213 825131.7425916529, 1369211.894929074 825581.5605392518, 1369125.767178121 826286.282626621, 1368994.248025809 827285.0703210802, 1368790.538871291 828903.554195428, 1368545.515397841 830795.1866964033, 1368406.513704913 831755.2418734914, 1368350.7156059 832194.002725605, 1368296.293078237 832484.0916801292, 1368185.739398894 832982.3435993881, 1368060.503322618 833528.1358070824, 1367987.274389928 833775.5540376155, 1367868.882410213 834219.7933971088, 1367783.355789585 834521.6481987286, 1367689.456151721 834851.4624636419, 1367568.805894812 835294.3618252305, 1367425.159145609 835815.5383325435, 1367280.965681453 836310.3326421381, 1367148.960187339 836745.1372695825, 1366968.317115292 837317.1031379146, 1366901.301249685 837539.3898256937, 1366579.668148534 838543.5763057156, 1366292.973913675 839503.9699226849, 1366134.515753648 839957.3958137374, 1365829.70569706 840800.0936084727, 1365654.142151732 841291.3907460336, 1365490.943554443 841837.9980410013, 1365373.962651541 842239.1580601522, 1365320.097018117 842659.8310269071, 1365291.2182638 ...

# %% [markdown]
# If we call `.plot()` and a GeoDataFrame, it will render a plot using the geometry column.

# %%
counties.plot();
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/geopandas/plotting.py in plot_polygon_collection(ax, geoms, values, color, cmap, vmin, vmax, **kwargs)
#      84     try:
# ---> 85         from descartes.patch import PolygonPatch
#      86     except ImportError:
#
# ModuleNotFoundError: No module named 'descartes'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-02fb9e9f6abe> in <module>
# ----> 1 counties.plot();
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/geodataframe.py in plot(self, *args, **kwargs)
#     548         from there.
#     549         """
# --> 550         return plot_dataframe(self, *args, **kwargs)
#     551
#     552     plot.__doc__ = plot_dataframe.__doc__
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/plotting.py in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, classification_kwds, **style_kwds)
#     425         return plot_series(df.geometry, cmap=cmap, color=color, ax=ax,
#     426                            figsize=figsize, markersize=markersize,
# --> 427                            **style_kwds)
#     428
#     429     # To accept pd.Series and np.arrays as column
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/plotting.py in plot_series(s, cmap, color, ax, figsize, **style_kwds)
#     295         values_ = values[poly_idx] if cmap else None
#     296         plot_polygon_collection(ax, polys, values_, facecolor=facecolor,
# --> 297                                 cmap=cmap, **style_kwds)
#     298
#     299     # plot all LineStrings and MultiLineString components in same collection
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/plotting.py in plot_polygon_collection(ax, geoms, values, color, cmap, vmin, vmax, **kwargs)
#      85         from descartes.patch import PolygonPatch
#      86     except ImportError:
# ---> 87         raise ImportError("The descartes package is required"
#      88                           " for plotting polygons in geopandas.")
#      89     from matplotlib.collections import PatchCollection
#
# ImportError: The descartes package is required for plotting polygons in geopandas.

# %% [markdown]
# If we want a larger plot, we can use `plt.subplots()` and set a figsize. When we create our plot, we need to specify that we want it to render on the axes we just created.

# %%
fig, ax = plt.subplots(figsize=(16,4))
counties.plot(ax = ax);

# %% [markdown]
# Since the axes are not conveying useful information, we can remove them.

# %%
fig, ax = plt.subplots(figsize=(16,4))
counties.plot(ax = ax)
ax.axis('off');

# %%
unemployment = pd.read_csv('data/unemployment.csv')

unemployment.head()

# %% [markdown]
# Now, we can merge the two together. If we put the GeoDataFrame on the left, the result will be a GeoDataFrame.

# %%
counties = pd.merge(left = counties, right = unemployment)
counties.head()

# %% [markdown]
# To color our map based on a column, we can use the `column` argument.

# %%
fig, ax = plt.subplots(figsize=(16,4))
counties.plot(column = 'unemployment_rate', 
              ax = ax)
ax.axis('off');

# %% [markdown]
# The default colormap is not great. We can change it by specifying the `cmap` argument. A list of named colormaps is available at https://matplotlib.org/3.1.1/gallery/color/colormap_reference.html.

# %%
fig, ax = plt.subplots(figsize=(16,4))
counties.plot(column = 'unemployment_rate', 
              cmap = 'Greys', 
              edgecolor = 'black', 
              ax = ax)
ax.axis('off');

# %%
fig, ax = plt.subplots(figsize=(16,4))
counties.plot(column = 'unemployment_rate', 
              cmap = 'Greys', 
              edgecolor = 'black', 
              legend = True,
              ax = ax)
ax.axis('off');

# %%
fig, ax = plt.subplots(figsize=(16,4))
counties.plot(column = 'unemployment_rate', 
              cmap = 'Greys', 
              edgecolor = 'black', 
              legend = True,
              ax = ax)
plt.title('Unemployment Rate by County, December 2018', fontsize = 14)
ax.axis('off');
